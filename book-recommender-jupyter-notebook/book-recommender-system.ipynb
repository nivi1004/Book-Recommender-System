# %%
import numpy as np
import pandas as pd

# %%
import pandas as pd

books = pd.read_csv('Books.csv')
users = pd.read_csv('Users.csv')
ratings = pd.read_csv('Ratings.csv')
# Out:
# C:\Users\91941\AppData\Local\Temp\ipykernel_22024\907619549.py:3: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   books = pd.read_csv('Books.csv')

# %%
books
# Out:
#               ISBN                                         Book-Title  \
# 0       0195153448                                Classical Mythology
# 1       0002005018                                       Clara Callan
# 2       0060973129                               Decision in Normandy
# 3       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4       0393045218                             The Mummies of Urumchi
# ...            ...                                                ...
# 271355  0440400988                         There's a Bat in Bunk Five
# 271356  0525447644                            From One to One Hundred
# 271357  006008667X  Lily Dale : The True Story of the Town that Ta...
# 271358  0192126040                        Republic (World's Classics)
# 271359  0767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#                  Book-Author Year-Of-Publication  \
# 0         Mark P. O. Morford                2002
# ...

# %%
books['Image-URL-M'][0]
# Out:
# 'http://images.amazon.com/images/P/0195153448.01.MZZZZZZZ.jpg'

# %%
users
# Out:
#         User-ID                            Location   Age
# 0             1                  nyc, new york, usa   NaN
# 1             2           stockton, california, usa  18.0
# 2             3     moscow, yukon territory, russia   NaN
# 3             4           porto, v.n.gaia, portugal  17.0
# 4             5  farnborough, hants, united kingdom   NaN
# ...         ...                                 ...   ...
# 278853   278854               portland, oregon, usa   NaN
# 278854   278855  tacoma, washington, united kingdom  50.0
# 278855   278856           brampton, ontario, canada   NaN
# 278856   278857           knoxville, tennessee, usa   NaN
# 278857   278858                dublin, n/a, ireland   NaN
#
# [278858 rows x 3 columns]

# %%
ratings
# Out:
#          User-ID         ISBN  Book-Rating
# 0         276725   034545104X            0
# 1         276726   0155061224            5
# 2         276727   0446520802            0
# 3         276729   052165615X            3
# 4         276729   0521795028            6
# ...          ...          ...          ...
# 1149775   276704   1563526298            9
# 1149776   276706   0679447156            0
# 1149777   276709   0515107662           10
# 1149778   276721   0590442449           10
# 1149779   276723  05162443314            8
#
# [1149780 rows x 3 columns]

# %%
print(books.shape)
print(ratings.shape)
print(users.shape)
# Out:
# (271360, 8)
# (1149780, 3)
# (278858, 3)

# %%
books.isnull().sum()
# Out:
# ISBN                   0
# Book-Title             0
# Book-Author            2
# Year-Of-Publication    0
# Publisher              2
# Image-URL-S            0
# Image-URL-M            0
# Image-URL-L            3
# dtype: int64

# %%
users.isnull().sum()
# Out:
# User-ID          0
# Location         0
# Age         110762
# dtype: int64

# %%
ratings.isnull().sum()
# Out:
# User-ID        0
# ISBN           0
# Book-Rating    0
# dtype: int64

# %%
books.duplicated().sum()
# Out:
# 0

# %%
ratings.duplicated().sum()
# Out:
# 0

# %%
books['lowercase_title'] = books['Book-Title'].str.lower()

# %% [markdown]
# ## Popularity Based Recommendation System

# %%
#min 250 people rated

ratings_with_name = ratings.merge(books,on='ISBN')
ratings_with_name
# Out:
#          User-ID        ISBN  Book-Rating  \
# 0         276725  034545104X            0
# 1         276726  0155061224            5
# 2         276727  0446520802            0
# 3         276729  052165615X            3
# 4         276729  0521795028            6
# ...          ...         ...          ...
# 1031131   276704  0876044011            0
# 1031132   276704  1563526298            9
# 1031133   276706  0679447156            0
# 1031134   276709  0515107662           10
# 1031135   276721  0590442449           10
#
#                                                 Book-Title        Book-Author  \
# 0                                     Flesh Tones: A Novel         M. J. Rose
# 1                                         Rites of Passage         Judith Rae
# 2                                             The Notebook    Nicholas Sparks
# 3                                           Help!: Level 1      Philip Prowse
# ...

# %%
ratings_with_name.shape
# Out:
# (1031136, 11)

# %%
ratings_with_name
# Out:
#          User-ID        ISBN  Book-Rating  \
# 0         276725  034545104X            0
# 1         276726  0155061224            5
# 2         276727  0446520802            0
# 3         276729  052165615X            3
# 4         276729  0521795028            6
# ...          ...         ...          ...
# 1031131   276704  0876044011            0
# 1031132   276704  1563526298            9
# 1031133   276706  0679447156            0
# 1031134   276709  0515107662           10
# 1031135   276721  0590442449           10
#
#                                                 Book-Title        Book-Author  \
# 0                                     Flesh Tones: A Novel         M. J. Rose
# 1                                         Rites of Passage         Judith Rae
# 2                                             The Notebook    Nicholas Sparks
# 3                                           Help!: Level 1      Philip Prowse
# ...

# %%
num_rating_df = ratings_with_name.groupby('Book-Title').count()['Book-Rating'].reset_index()
num_rating_df.rename(columns={'Book-Rating':'num_ratings'},inplace=True)
num_rating_df
# Out:
#                                                Book-Title  num_ratings
# 0        A Light in the Storm: The Civil War Diary of ...            4
# 1                                   Always Have Popsicles            1
# 2                    Apple Magic (The Collector's series)            1
# 3        Ask Lily (Young Women of Faith: Lily Series, ...            1
# 4        Beyond IBM: Leadership Marketing and Finance ...            1
# ...                                                   ...          ...
# 241066                                      Ã?Â?lpiraten.            2
# 241067                     Ã?Â?rger mit Produkt X. Roman.            4
# 241068                                Ã?Â?sterlich leben.            1
# 241069                              Ã?Â?stlich der Berge.            3
# 241070                                  Ã?Â?thique en toc            2
#
# [241071 rows x 2 columns]

# %%
avg_rating_df = ratings_with_name.groupby('Book-Title').agg(avg_ratings=('Book-Rating', 'mean')).reset_index()
avg_rating_df
# Out:
#                                                Book-Title  avg_ratings
# 0        A Light in the Storm: The Civil War Diary of ...     2.250000
# 1                                   Always Have Popsicles     0.000000
# 2                    Apple Magic (The Collector's series)     0.000000
# 3        Ask Lily (Young Women of Faith: Lily Series, ...     8.000000
# 4        Beyond IBM: Leadership Marketing and Finance ...     0.000000
# ...                                                   ...          ...
# 241066                                      Ã?Â?lpiraten.     0.000000
# 241067                     Ã?Â?rger mit Produkt X. Roman.     5.250000
# 241068                                Ã?Â?sterlich leben.     7.000000
# 241069                              Ã?Â?stlich der Berge.     2.666667
# 241070                                  Ã?Â?thique en toc     4.000000
#
# [241071 rows x 2 columns]

# %%
popular_df = num_rating_df.merge(avg_rating_df,on='Book-Title')
popular_df
# Out:
#                                                Book-Title  num_ratings  \
# 0        A Light in the Storm: The Civil War Diary of ...            4
# 1                                   Always Have Popsicles            1
# 2                    Apple Magic (The Collector's series)            1
# 3        Ask Lily (Young Women of Faith: Lily Series, ...            1
# 4        Beyond IBM: Leadership Marketing and Finance ...            1
# ...                                                   ...          ...
# 241066                                      Ã?Â?lpiraten.            2
# 241067                     Ã?Â?rger mit Produkt X. Roman.            4
# 241068                                Ã?Â?sterlich leben.            1
# 241069                              Ã?Â?stlich der Berge.            3
# 241070                                  Ã?Â?thique en toc            2
#
#         avg_ratings
# 0          2.250000
# 1          0.000000
# 2          0.000000
# 3          8.000000
# ...

# %%
popular_df = popular_df[popular_df['num_ratings']>=250].sort_values('avg_ratings',ascending=False).head(50)

# %%
num_rating_df = ratings_with_name.groupby('Book-Title').count()['Book-Rating'].reset_index()
num_rating_df.rename(columns={'Book-Rating':'num_ratings'},inplace=True)
avg_rating_df = ratings_with_name.groupby('Book-Title').agg(avg_ratings=('Book-Rating', 'mean')).reset_index()
popular_df = num_rating_df.merge(avg_rating_df,on='Book-Title')
popular_df = popular_df[popular_df['num_ratings']>=250].sort_values('avg_ratings',ascending=False).head(50)
popular_df = popular_df.merge(books,on='Book-Title').drop_duplicates('Book-Title')[['Book-Title','Book-Author','Image-URL-M','num_ratings','avg_ratings']]

# %%
popular_df
# Out:
#                                             Book-Title  \
# 0    Harry Potter and the Prisoner of Azkaban (Book 3)
# 3         Harry Potter and the Goblet of Fire (Book 4)
# 5       Harry Potter and the Sorcerer's Stone (Book 1)
# 9    Harry Potter and the Order of the Phoenix (Boo...
# 13    Harry Potter and the Chamber of Secrets (Book 2)
# 16   The Hobbit : The Enchanting Prelude to The Lor...
# 17   The Fellowship of the Ring (The Lord of the Ri...
# 26   Harry Potter and the Sorcerer's Stone (Harry P...
# 28      The Two Towers (The Lord of the Rings, Part 2)
# 39                               To Kill a Mockingbird
# 47                                   The Da Vinci Code
# 53                  The Five People You Meet in Heaven
# 55                              The Catcher in the Rye
# 62                           The Lovely Bones: A Novel
# 63                                                1984
# 72                            Prodigal Summer: A Novel
# ...

# %% [markdown]
# ## Collaborative Filtering

# %%
ratings_with_name
# Out:
#          User-ID        ISBN  Book-Rating  \
# 0         276725  034545104X            0
# 1         276726  0155061224            5
# 2         276727  0446520802            0
# 3         276729  052165615X            3
# 4         276729  0521795028            6
# ...          ...         ...          ...
# 1031131   276704  0876044011            0
# 1031132   276704  1563526298            9
# 1031133   276706  0679447156            0
# 1031134   276709  0515107662           10
# 1031135   276721  0590442449           10
#
#                                                 Book-Title        Book-Author  \
# 0                                     Flesh Tones: A Novel         M. J. Rose
# 1                                         Rites of Passage         Judith Rae
# 2                                             The Notebook    Nicholas Sparks
# 3                                           Help!: Level 1      Philip Prowse
# ...

# %%
ratings_with_name.groupby('User-ID').count()
# Out:
#          ISBN  Book-Rating  Book-Title  Book-Author  Year-Of-Publication  \
# User-ID
# 2           1            1           1            1                    1
# 8          17           17          17           17                   17
# 9           3            3           3            3                    3
# 10          1            1           1            1                    1
# 12          1            1           1            1                    1
# ...       ...          ...         ...          ...                  ...
# 278846      1            1           1            1                    1
# 278849      4            4           4            4                    4
# 278851     23           23          23           23                   23
# 278852      1            1           1            1                    1
# 278854      8            8           8            8                    8
#
#          Publisher  Image-URL-S  Image-URL-M  Image-URL-L  lowercase_title
# ...

# %%
ratings_with_name.groupby('User-ID').count()['Book-Rating']
# Out:
# User-ID
# 2          1
# 8         17
# 9          3
# 10         1
# 12         1
#           ..
# 278846     1
# 278849     4
# 278851    23
# 278852     1
# 278854     8
# Name: Book-Rating, Length: 92106, dtype: int64

# %%
x = ratings_with_name.groupby('User-ID').count()['Book-Rating']>200
active_users = x[x].index
filtered_rating = ratings_with_name[ratings_with_name['User-ID'].isin(active_users)]

# %%
y = filtered_rating.groupby('Book-Title').count()['Book-Rating']>=50
famous_books = y[y].index
final_ratings = filtered_rating[filtered_rating['Book-Title'].isin(famous_books)]

# %%
final_ratings
# Out:
#          User-ID        ISBN  Book-Rating  \
# 1150      277427  002542730X           10
# 1163      277427  0060930535            0
# 1165      277427  0060934417            0
# 1168      277427  0061009059            9
# 1174      277427  006440188X            0
# ...          ...         ...          ...
# 1029196   275970  1400031354            0
# 1029197   275970  1400031362            0
# 1029270   275970  1573229725            0
# 1029309   275970  1586210661            9
# 1029310   275970  1586212230            0
#
#                                                 Book-Title  \
# 1150     Politically Correct Bedtime Stories: Modern Ta...
# 1163                         The Poisonwood Bible: A Novel
# 1165                                    Bel Canto: A Novel
# 1168     One for the Money (Stephanie Plum Novels (Pape...
# 1174                                     The Secret Garden
# ...                                                    ...
# ...

# %%
final_ratings.head()
# Out:
#       User-ID        ISBN  Book-Rating  \
# 1150   277427  002542730X           10
# 1163   277427  0060930535            0
# 1165   277427  0060934417            0
# 1168   277427  0061009059            9
# 1174   277427  006440188X            0
#
#                                              Book-Title  \
# 1150  Politically Correct Bedtime Stories: Modern Ta...
# 1163                      The Poisonwood Bible: A Novel
# 1165                                 Bel Canto: A Novel
# 1168  One for the Money (Stephanie Plum Novels (Pape...
# 1174                                  The Secret Garden
#
#                   Book-Author Year-Of-Publication                  Publisher  \
# 1150        James Finn Garner                1994  John Wiley &amp; Sons Inc
# 1163       Barbara Kingsolver                1999                  Perennial
# 1165             Ann Patchett                2002                  Perennial
# ...

# %%
# Ensure that the title used in the pivot table is the lowercase version
filtered_rating = ratings_with_name[ratings_with_name['User-ID'].isin(active_users)]
famous_books = filtered_rating.groupby('lowercase_title').count()['Book-Rating'] >= 50
famous_books = famous_books[famous_books].index

final_ratings = filtered_rating[filtered_rating['lowercase_title'].isin(famous_books)]

# Create the pivot table using the lowercase title
pt = final_ratings.pivot_table(index='lowercase_title', columns='User-ID', values='Book-Rating')
pt.fillna(0, inplace=True)

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity_score = cosine_similarity(pt)
similarity_score
# Out:
# array([[1.        , 0.10255025, 0.01220856, ..., 0.01634679, 0.12110367,
#         0.07347567],
#        [0.10255025, 1.        , 0.2364573 , ..., 0.17837034, 0.07446129,
#         0.16773875],
#        [0.01220856, 0.2364573 , 1.        , ..., 0.15675217, 0.04558758,
#         0.04938579],
#        ...,
#        [0.01634679, 0.17837034, 0.15675217, ..., 1.        , 0.12563693,
#         0.2999273 ],
#        [0.12110367, 0.07446129, 0.04558758, ..., 0.12563693, 1.        ,
#         0.07085128],
#        [0.07347567, 0.16773875, 0.04938579, ..., 0.2999273 , 0.07085128,
#         1.        ]])

# %%
cosine_similarity(pt).shape
# Out:
# (718, 718)

# %%
similarity_score[0]
# Out:
# array([1.        , 0.10255025, 0.01220856, 0.        , 0.04316046,
#        0.05367224, 0.02774901, 0.08216491, 0.13732869, 0.        ,
#        0.03261686, 0.03667591, 0.02322418, 0.06766487, 0.02083978,
#        0.09673735, 0.08303112, 0.13388865, 0.11153543, 0.05100411,
#        0.02517784, 0.11706383, 0.        , 0.14333793, 0.07847534,
#        0.06150451, 0.08723968, 0.        , 0.0987527 , 0.07600328,
#        0.00751764, 0.01473221, 0.        , 0.07965814, 0.04522617,
#        0.01525489, 0.09495938, 0.0182307 , 0.02610465, 0.07984012,
#        0.12343843, 0.12167134, 0.0569124 , 0.08354155, 0.07886098,
#        0.08785938, 0.05491435, 0.0548505 , 0.27026514, 0.09779123,
#        0.06016046, 0.08958835, 0.06748675, 0.        , 0.04468098,
#        0.01920872, 0.        , 0.05629067, 0.00557964, 0.07877059,
#        0.05219479, 0.18908177, 0.        , 0.01240656, 0.02848981,
#        0.04279502, 0.12680125, 0.16566735, 0.        , 0.13357242,
# ...

# %%
def recommend(book_name):
    #index fetch
    book_name = book_name.lower()

    # Index fetch using lowercase title
    index = np.where(pt.index == book_name)[0][0]
    similar_items = sorted(list(enumerate(similarity_score[index])), key=lambda x: x[1], reverse=True)[1:5]

    data = []
    for i in similar_items:
        item = []
        # Use the original case title for display
        temp_df = books[books['lowercase_title'] == pt.index[i[0]]]
        item.extend(list(temp_df.drop_duplicates('Book-Title')['Book-Title'].values))
        item.extend(list(temp_df.drop_duplicates('Book-Author')['Book-Author'].values))
        item.extend(list(temp_df.drop_duplicates('Book-Title')['Image-URL-M'].values))
        data.append(item)
    return data

# %%
recommend('1984')
# Out:
# [['Animal Farm',
#   'George Orwell',
#   'http://images.amazon.com/images/P/0451526341.01.MZZZZZZZ.jpg'],
#  ["The Handmaid's Tale",
#   'Margaret Atwood',
#   'http://images.amazon.com/images/P/0449212602.01.MZZZZZZZ.jpg'],
#  ['Brave New World',
#   'Aldous Huxley',
#   'http://images.amazon.com/images/P/0060809833.01.MZZZZZZZ.jpg'],
#  ['The Vampire Lestat (Vampire Chronicles, Book II)',
#   'ANNE RICE',
#   'http://images.amazon.com/images/P/0345313860.01.MZZZZZZZ.jpg']]

# %%
recommend('Message in a Bottle')
# Out:
# [['Nights in Rodanthe',
#   'Nicholas Sparks',
#   'http://images.amazon.com/images/P/0446531332.01.MZZZZZZZ.jpg'],
#  ['The Mulberry Tree',
#   'Jude Deveraux',
#   'http://images.amazon.com/images/P/0743437640.01.MZZZZZZZ.jpg'],
#  ['A Walk to Remember',
#   'Nicholas Sparks',
#   'http://images.amazon.com/images/P/0446608955.01.MZZZZZZZ.jpg'],
#  ["River's End",
#   'Nora Roberts',
#   'http://images.amazon.com/images/P/0515127833.01.MZZZZZZZ.jpg']]

# %%
recommend('The Notebook')
# Out:
# [['A Walk to Remember',
#   'Nicholas Sparks',
#   'http://images.amazon.com/images/P/0446608955.01.MZZZZZZZ.jpg'],
#  ['The Rescue',
#   'Nicholas Sparks',
#   'Elizabeth Faucher',
#   'Suzanne Robinson',
#   'http://images.amazon.com/images/P/0446610399.01.MZZZZZZZ.jpg'],
#  ['One Door Away from Heaven',
#   'One Door Away From Heaven',
#   'Dean R. Koontz',
#   'DEAN KOONTZ',
#   'http://images.amazon.com/images/P/0553582755.01.MZZZZZZZ.jpg',
#   'http://images.amazon.com/images/P/0553528947.01.MZZZZZZZ.jpg'],
#  ['Toxin',
#   'Robin Cook',
#   'http://images.amazon.com/images/P/0425166619.01.MZZZZZZZ.jpg']]

# %%
recommend('The Da Vinci Code')
# Out:
# [['Angels &amp; Demons',
#   'Dan Brown',
#   'http://images.amazon.com/images/P/0671027360.01.MZZZZZZZ.jpg'],
#  ['Touching Evil',
#   'Kay Hooper',
#   'http://images.amazon.com/images/P/0553583441.01.MZZZZZZZ.jpg'],
#  ['Saving Faith',
#   'David Baldacci',
#   'DAVID BALDACCI',
#   'http://images.amazon.com/images/P/0446608890.01.MZZZZZZZ.jpg'],
#  ["The Sweet Potato Queens' Book of Love",
#   'JILL CONNER BROWNE',
#   'http://images.amazon.com/images/P/0609804138.01.MZZZZZZZ.jpg']]

# %%
import pickle
pickle.dump(popular_df,open('popular.pkl','wb'))

# %%
pickle.dump(pt,open('pt.pkl','wb'))
pickle.dump(books,open('books.pkl','wb'))
pickle.dump(similarity_score,open('similarity_score.pkl','wb'))

# %%
from sklearn.metrics import mean_squared_error
import numpy as np

# Assuming you have actual ratings and predicted ratings
# These should be in the same format and correspond to each other
actual_ratings = np.array([actual_rating1, actual_rating2, ...])  # Actual ratings from your dataset
predicted_ratings = np.array([predicted_rating1, predicted_rating2, ...])  # Ratings predicted by the model

# Calculate RMSE
rmse = np.sqrt(mean_squared_error(actual_ratings, predicted_ratings))
print(f'RMSE: {rmse}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[523], line 6
#       2 import numpy as np
#       4 # Assuming you have actual ratings and predicted ratings
#       5 # These should be in the same format and correspond to each other
# ----> 6 actual_ratings = np.array([actual_rating1, actual_rating2, ...])  # Actual ratings from your dataset
#       7 predicted_ratings = np.array([predicted_rating1, predicted_rating2, ...])  # Ratings predicted by the model
#       9 # Calculate RMSE
#
# NameError: name 'actual_rating1' is not defined
